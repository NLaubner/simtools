# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from src.simulation import load_config, run_monte_carlo

# %%
cfg = load_config("../configs/params.json")
results, summary = run_monte_carlo(cfg, return_details=True)

summary
# Out:
#                              metric   value
# 0     overall_infection_probability  0.1915
# 1     p_infection_happens_at_street  0.0015
# 2    p_infection_happens_at_lecture  0.0897
# 3  p_infection_happens_at_cafeteria  0.0717
# 4        p_infection_happens_at_bib  0.0286
